# %% [markdown]
# # Course outline
#
#
# ## Part 1: The theoretical part ...
#
# ### Motivation and get it going
# * [Introduction](00_Introduction.ipynb)
#  * [A python primer](01_python_introduction.ipynb)
#  * [Getting started](01_GettingStarted.ipynb)
# ----
#
# ### General python introduction (2x)
#  * What is a program?
#  * [Python basics](sub/koldunov/02 - Python basics.ipynb)
#  * [First steps ... basic data types, variables and operations](sub/jrjohansson/Lecture-1-Introduction-to-Python-Programming.ipynb)
#  * [Everything is an object ... About functions and classes](02_object.ipynb)
#  * [Some words about what is *equal*](02_equal.ipynb)
#  * Keeping control of your programs ... (for, while, break, continue, if)
# ----
#
# ### Scientific modules in python
#
# * [Numerical python (numpy)](sub/koldunov/03 - NumPy arrays.ipynb) (1x)
#  * [Some more advanced numpy stuff](sub/jrjohansson/Lecture-2-Numpy.ipynb)
#  * Masked arrays
# * Plotting in python (matplotlib)
#  * [Your best friend](http://matplotlib.org/gallery.html)
#  * [Plotting basics](sub/koldunov/05 - Graphs and maps - Matplotlib and Basemap.ipynb)
#  * [Getting into more detail ...](sub/jrjohansson/Lecture-4-Matplotlib.ipynb)
#  * Map plots: [Basemap](sub/koldunov/05 - Graphs and maps - Matplotlib and Basemap.ipynb)
#  * Map plots: [Cartopy](cartopy.ipynb) TBD
# * [Handling different data formats](sub/koldunov/04 - Work with different data formats.ipynb)
#
# * Scientific data analysis (scipy)
#  * Some basics (regression analysis, statistical testing, interpolation)
#  * [A bit more advanced stuff](sub/jrjohansson/Lecture-3-Scipy.ipynb)
#
#
# ### Geospatial data handling
#
# * Handling geospatial data (raster and vector); gdal and other cool tools (2x)
# * [Modules for geoscientists](sub/koldunov/07 - Other modules for geoscientists.ipynb)
#  * [GDAL virtual files and OSGEO ... ](xxx_gdal.ipynb)
# * Interpolation and data fitting (1x)
# * [Using python for GIS automatization ... the ArcGIS example](python_gis.ipynb) TBD BEN
#
# ### Special aspects
#
# * making my code faster ... how to achieve a speedup by a factor of $10^4$ (numba, multiprocessing, cython)
#   * [High performance computing (HPC)](sub/jrjohansson/Lecture-6B-HPC.ipynb)
#  * [code versioning and collaborative coding](sub/jrjohansson/Lecture-7-Revision-Control-Software.ipynb)
#  * making my code better (PEP8 standard, testing)
#  * automated testing and continuous integration
#  * [Time series analysis: `pandas`](sub/koldunov/06 - Time series analysis.ipynb)
#
# ### For the geeks
#
# * [Replace the paper and pencil ... symbolic math in python](sub/jrjohansson/Lecture-5-Sympy.ipynb)
# * [Integration of existing Fortran and C code](sub/jrjohansson/Lecture-6A-Fortran-and-C.ipynb)
#
#
#
#
#
#
#
#
#
#
#
# ## Part 2: Let's hack ... the practical part
#
# * Your / our project
# * Collaborative applied coding project
