# %% [markdown]
# # Vorlesung 1
#
# $y = x^2$

# %%
c=2.+2.
print(c)
# Out:
# 4.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(100)
y = x**2.

plt.plot(x,y)
plt.grid()
